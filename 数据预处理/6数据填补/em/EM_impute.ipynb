# %%
import pandas as pd
diabetes=pd.read_csv('../../4+5数据集的删除和划分和规范化/train_norm_impute_no.csv',engine='python')
diabetes
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.575790  0.830241      -0.001246       0.598041       NaN  0.133325
# 1      -0.887567 -1.230956      -0.482772       0.006269       NaN -0.833138
# 2       1.161133  1.975350      -0.643280            NaN       NaN -1.288756
# 3      -0.887567 -1.100086      -0.482772      -0.585503 -0.491434 -0.626039
# 4      -1.180239  0.470349      -2.569383       0.598041  0.064473  1.444954
# 5       0.283118 -0.216716       0.159262            NaN       NaN -0.971204
# 6      -0.302225 -1.459977      -1.766840       0.302155 -0.536507 -0.225647
# 7       1.746476 -0.249434            NaN            NaN       NaN  0.368038
# 8      -0.594896  2.433393      -0.161755       1.584327  2.881567 -0.294680
# 9       1.161133  0.077740       1.924856            NaN       NaN       NaN
# 10     -0.009553 -0.413021       1.603839            NaN       NaN  0.685590
# ...

# %%
import impyute as impy
